# %% [markdown]
# # Deep Learning

# %% [markdown]
# ## HW1- problem 2- Support Vector Machine (100 + 10 pts)

# %% [markdown]
# ### Please fill this part
#
#
# 1.   Full Name: Saman Soleimani Roudi
# 2.   Student Number: 400206284
#
#
# *You are just allowded to change those parts that start with "TO DO". Please do not change other parts.*
#
# *It is highly recommended to read each codeline carefully and try to understand what it exactly does. Best of luck and have fun!*

# %%
# You are not allowed to import other packages.
import numpy as np
import pandas as pd
 
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.svm import SVC

import cvxopt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #### About the Data:
# Heart diseases, also known as [Cardiovascular diseases (CVDs)](https://en.wikipedia.org/wiki/Cardiovascular_disease), are the first cause of death worldwide, taking an estimated 17.9 million lives each year which is about 32% of all deaths all over the world.
#
# In the present HomeWork, we are going to implement Support Vector Machines (SVM) algorithm that determines which patient is in danger and which is not.
#
# For this perpose, `Heart_Disease_Dataset.csv` file can be used that is attached to the HomeWork folder. Use `Dataset_Description.pdf` for more detail.

# %%
df = pd.read_csv("/content/drive/MyDrive/HW1/data/Heart_Disease_Dataset.csv")

# %% [markdown]
# ### Pre-Processing - (40 pts)

# %% [markdown]
# #### Exploratory Data Analysis (EDA):
# In statistics, exploratory data analysis is an approach to analyze datasets to summarize their main characteristics, often using statistical graphics and other data visualization methods.
#
# This is a general approach that should be applied when you encounter a dataset.

# %%
###############################################################################
## TODO: Find the shape of the dataset.                                      ##
###############################################################################
shape = df.shape
print("shape of dataset is: " , shape)

###############################################################################
## TODO: Check if there is missing entries in the dataset columnwise.        ##
###############################################################################
missings = df.isnull().sum().sum()
#missing is 0, so the dataset has not missing value
print("this dataset has not missing value")

###############################################################################
## TODO: Check whether the dataset is balanced or not.                       ##
## If the difference between 2 classes was less than 100 for our dataset,    ##
## it is called "ballanced".                                                 ##
###############################################################################
diff_2_classes= abs(df['target'].value_counts()[1] - df['target'].value_counts()[0])
#Difference between 2 classes is 68, so the dataset is balanced
print("ballanced: True")

###############################################################################
## TODO: plot the age distirbution and gender distrbution for both normal    ##
## and heart diseses patients.(4 plots)                                      ##
###############################################################################

sns.displot(df.loc[df['target']==1]['age'],kde='kde',discrete=True).set(title='Age Distribution of Heart Diseses Patients')

sns.displot(df.loc[df['target']==0]['age'],kde='kde',discrete=True).set(title='Age Distribution of Normal People')

sns.displot(df.loc[df['target']==1]['sex'],kde='kde').set(title='Sex Distribution of Heart Diseses Patients')

sns.displot(df.loc[df['target']==0]['sex'],kde='kde').set(title='Sex Distribution of Normal People')
# Out:
# shape of dataset is:  (1190, 12)
# this dataset has not missing value
# ballanced: True

# %% [markdown]
# #### Question 1: What do you conclude from the plots?
# #### Answer: Females and young people are healthier than males and older people.

# %% [markdown]
# #### Outlier Detection & Removal:
# We will filter ouliers using Z-test.

# %% [markdown]
# ![outlier.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Z-test formula:
# \begin{equation*}
#     Z = \bigg|\frac {x - mu} {std}\bigg|
# \end{equation*}

# %%
################################################################################
## TODO: Suppose that, based on our prior knowledge, we know some columns have##
## outliers. Calculate z-score for each featuer and determine the outliers    ##
## with threshold=3, then eliminate them. Target dataframe has(1173,12)shape. ##
################################################################################
df_Outlier_Removed = pd.DataFrame.copy(df)
columns = ["age","resting bp s","cholesterol","max heart rate"]
threshold = 3
columns = ["age","resting bp s","cholesterol","max heart rate"]
df_standard=abs(df_Outlier_Removed[columns]-pd.DataFrame.mean(df_Outlier_Removed[columns]))/pd.DataFrame.std(df_Outlier_Removed[columns])
df_Outlier_Removed.drop(np.unique(np.where(df_standard[columns]>threshold)[0]), inplace=True)
df_Outlier_Removed = df_Outlier_Removed.reset_index(drop=True)
df_Outlier_Removed
################################################################################
#                                 END OF YOUR CODE                             #
################################################################################
# Out:
#       age  sex  chest pain type  resting bp s  cholesterol  \
# 0      40    1                2           140          289
# 1      49    0                3           160          180
# 2      37    1                2           130          283
# 3      48    0                4           138          214
# 4      54    1                3           150          195
# ...   ...  ...              ...           ...          ...
# 1168   45    1                1           110          264
# 1169   68    1                4           144          193
# 1170   57    1                4           130          131
# 1171   57    0                2           130          236
# 1172   38    1                3           138          175
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0             172                0
# 1                       0            0             156                0
# 2                       0            1              98                0
# 3                       0            0             108                1
# 4                       0            0             122                0
# ...                   ...          ...             ...              ...
# 1168                    0            0             132                0
# 1169                    1            0             141                0
# 1170                    0            0             115                1
# 1171                    0            2             174                0
# 1172                    0            0             173                0
#
#       oldpeak  ST slope  target
# 0         0.0         1       0
# 1         1.0         2       1
# 2         0.0         1       0
# 3         1.5         2       1
# 4         0.0         1       0
# ...       ...       ...     ...
# 1168      1.2         2       1
# 1169      3.4         2       1
# 1170      1.2         2       1
# 1171      0.0         2       1
# 1172      0.0         1       0
#
# [1173 rows x 12 columns]

# %% [markdown]
# #### Feature Engineering:
# Sometimes the collected data are raw; they are either incompatible with your model or hinders its performance. That’s when feature engineering comes to rescue. It encompasses preprocessing techniques to compile a dataset by extracting features from raw data.

# %%
################################################################################
## TODO: Normalize numerical features to be between 0 and 1                   ##
## Note that just numerical fetures should be normalized. type of features is ##
## determined in dataset description file.                                    ##
################################################################################
columns = ["age","resting bp s","cholesterol","max heart rate","oldpeak"]
df_Raw_Processed = pd.DataFrame.copy(df_Outlier_Removed)
df_Raw_Processed[columns] = (df_Raw_Processed[columns]-pd.DataFrame.min(df_Raw_Processed[columns]))/(pd.DataFrame.max(df_Raw_Processed[columns]) - pd.DataFrame.min(df_Raw_Processed[columns]))
df_Raw_Processed
################################################################################
#                                 END OF YOUR CODE                             #
################################################################################
# Out:
#            age  sex  chest pain type  resting bp s  cholesterol  \
# 0     0.244898    1                2      0.571429     0.588595
# 1     0.428571    0                3      0.761905     0.366599
# 2     0.183673    1                2      0.476190     0.576375
# 3     0.408163    0                4      0.552381     0.435845
# 4     0.530612    1                3      0.666667     0.397149
# ...        ...  ...              ...           ...          ...
# 1168  0.346939    1                1      0.285714     0.537678
# 1169  0.816327    1                4      0.609524     0.393075
# 1170  0.591837    1                4      0.476190     0.266802
# 1171  0.591837    0                2      0.476190     0.480652
# 1172  0.204082    1                3      0.552381     0.356415
#
#       fasting blood sugar  resting ecg  max heart rate  exercise angina  \
# 0                       0            0        0.777778                0
# 1                       0            0        0.659259                0
# 2                       0            1        0.229630                0
# 3                       0            0        0.303704                1
# 4                       0            0        0.407407                0
# ...                   ...          ...             ...              ...
# 1168                    0            0        0.481481                0
# 1169                    1            0        0.548148                0
# 1170                    0            0        0.355556                1
# 1171                    0            2        0.792593                0
# 1172                    0            0        0.785185                0
#
#        oldpeak  ST slope  target
# 0     0.295455         1       0
# 1     0.409091         2       1
# 2     0.295455         1       0
# 3     0.465909         2       1
# 4     0.295455         1       0
# ...        ...       ...     ...
# 1168  0.431818         2       1
# 1169  0.681818         2       1
# 1170  0.431818         2       1
# 1171  0.295455         2       1
# 1172  0.295455         1       0
#
# [1173 rows x 12 columns]

# %% [markdown]
# ### SVM - (60 pts)

# %% [markdown]
# #### spliting data

# %%
# The original dataset labels is 0 and 1 and in the following code we change it to -1 and 1. 
df = pd.DataFrame.copy(df_Raw_Processed)
df.target.replace(0 , -1 , inplace = True) 

# Turn pandas dataframe to numpy array type
df = df.to_numpy()

# Splitting data into train and test part. 70% for train and 30% for test
train = df[:int(len(df) * 0.7)]
test = df[int(len(df) * 0.7):]

# Getting features 
X_train = train[: , :-1]
y_train = train[: , -1]

# Getting labels
X_test = test[: , :-1]
y_test = test[: , -1]

# shapes should be: 
# Train: (821, 11) (821,)
# Test: (352, 11) (352,)
print("Train: ", X_train.shape ,y_train.shape)
print("Test: " ,X_test.shape ,y_test.shape)
# Out:
# Train:  (821, 11) (821,)
# Test:  (352, 11) (352,)

# %% [markdown]
# #### SVM Using sklearn:
# Use the standard libarary SVM classifier (SVC) on the training data, and then test the classifier on the test data. You will need to call SVM with 3 kernels: (1) Linear, (2) Polynomial and (3) RBF. You can change C to achive better results. For "RBF" find "gamma" witch takes 90% accuracy, at least. For polynomial kernel you are allowed to change "degree" to find best results.
#
# For each kernel, reportting the followings is required:
# Accuracy, Precision, Recall, F1score.

# %%
def classification_report(y_true, y_pred):
    #################################################################################
    ## TODO: Define a function that returns the followings:                        ##
    ## Accuracy, Precision, Recall, F1score.                                       ##
    #################################################################################
    TP = len(np.where(y_pred[np.where(y_test == 1)[0]] == 1)[0])
    FP  =len(np.where(y_test == 1)[0]) - TP
    TN = len(np.where(y_pred[np.where(y_test == -1)[0]] == -1)[0])
    FN  =len(np.where(y_test == -1)[0]) - TN
    Accuracy = (TP+TN)/(TP+TN+FP+FN) 
    Precision = (TP)/(TP+FP)
    Recall = (TP)/(TP+FN)
    F1score = (2*TP)/(2*TP+FP+FN)
    #################################################################################
    #                                 END OF YOUR CODE                              #
    #################################################################################
    return Accuracy, Precision, Recall, F1score

# %%
#########################################################################################
## TODO: Use svm of sklearn package (imported above) with 3 kernels.                   ##
## You should define model, fit using X_train, predict using X_test.                   ##
## your predictions known as y_pred.                                                   ##
## then use classification_report function to evaluate model.                          ##
#########################################################################################

# linear kernel

SVCClf = SVC(kernel = 'linear')
SVCClf.fit(X_train, y_train)
y_pred = SVCClf.predict(X_test)
print("results of sklearn svm linear kernel:", classification_report(y_test, y_pred))


# polynomial kernel

SVCClf = SVC(kernel = 'poly')
SVCClf.fit(X_train, y_train)
y_pred = SVCClf.predict(X_test)
print("results of sklearn svm polynomial kernel:", classification_report(y_test, y_pred))


# rbf kernel
SVCClf = SVC(kernel = 'rbf')
SVCClf.fit(X_train, y_train)
y_pred = SVCClf.predict(X_test)
print("results of sklearn svm RBF kernel:", classification_report(y_test, y_pred))


#########################################################################################
#                                      END OF YOUR CODE                                 #
#########################################################################################
# Out:
# results of sklearn svm linear kernel: (0.7869318181818182, 0.7515527950310559, 0.7756410256410257, 0.7634069400630915)
# results of sklearn svm polynomial kernel: (0.7840909090909091, 0.7018633540372671, 0.8014184397163121, 0.7483443708609272)
# results of sklearn svm RBF kernel: (0.7698863636363636, 0.7577639751552795, 0.7439024390243902, 0.7507692307692307)

# %% [markdown]
# #### SVM:
# Now that you know how the standard library SVM works on the dataset, attempt to implement your own version of SVM. Implement SVM using Quadratic Programming(QP) approach. Remember that SVM objective fuction with QP is:
#
# \begin{equation*}
#     min_{\alpha}\quad\frac{1}{2}\alpha^T\,Q\,\alpha-1^T\,\alpha\\
#     s.t.\qquad y^T\,\alpha=0,\,\alpha\ge0
# \end{equation*}
#
# where:
# \begin{equation*}
#     Q_{i,j}=y_i\,y_j\,\langle x_i\,,\,x_j\rangle
# \end{equation*}
#
# and:
# \begin{equation*}
#     \text{if}\;(\alpha_n>0)\;\text{then}\;x_n\;\text{is a  support vector}
# \end{equation*}
#
# For this perpose, complete the following code. You are allowed to use "cvxopt" package. It's an optimization package for Quadratic Programming. Below is the user's guide for the QP from CVXOPT:
#
# [Quadratic Programming](https://cvxopt.org/userguide/coneprog.html#quadratic-programming)

# %%
# Hide cvxopt output
cvxopt.solvers.options["show_progress"] = False

#####################################################################################
## TODO: Use the information from the lecture slides to formulate the SVM          ##
## kernels. These kernel functions will be called in the SVM class.                ##
#####################################################################################

def linear_kernel(x1, x2, gamma):
    return np.dot(x1, x2)

def polynomial_kernel(x1, x2, gamma, degree=3, coef0=0):
    return (gamma*np.dot(x1, x2)+coef0) ** degree

def rbf_kernel(x1, x2, gamma):
    return np.exp(-gamma*np.linalg.norm(x1-x2)**2)

def sigmoid_kernel(x1, x2, gamma, coef0=0):
    return np.tanh(gamma*np.dot(x1, x2)+coef0)

#####################################################################################
#                                   END OF YOUR CODE                                #
#####################################################################################


class MySVM(object):
    def __init__(self, kernel=linear_kernel, C=None):
        self.kernel = kernel
        self.C = C
        if self.C is not None: self.C = float(self.C)

    def fit(self, X, y, gamma):
        n_samples, n_features = X.shape
        self.gamma = gamma
        #####################################################################################
        ## TODO: Compute Gram matrix "K" for the given kernel.                             ##
        #####################################################################################        
        K = np.zeros((n_samples, n_samples))
        for i in range(n_samples):
            for j in range(n_samples):
                K[i,j] = self.kernel(X[i], X[j], self.gamma)
        #####################################################################################
        #                                   END OF YOUR CODE                                #
        #####################################################################################


        #####################################################################################
        ## TODO: Setup SVM objective function in QP form (Notation from attached link).    ##
        ## Guidance: G and h have defferent definition if C is used or not.                ##
        #####################################################################################
        P = cvxopt.matrix(np.outer(y,y) * K)
        q = cvxopt.matrix(np.ones(n_samples) * -1)
        A = cvxopt.matrix(y, (1,n_samples))
        b = cvxopt.matrix(0.0)

        if self.C is None:
            G = cvxopt.matrix(np.diag(np.ones(n_samples) * -1))
            h = cvxopt.matrix(np.zeros(n_samples))
        else:
            tmp1 = np.diag(np.ones(n_samples) * -1)
            tmp2 = np.identity(n_samples)
            G = cvxopt.matrix(np.vstack((tmp1, tmp2)))
            tmp1 = np.zeros(n_samples)
            tmp2 = np.ones(n_samples) * self.C
            h = cvxopt.matrix(np.hstack((tmp1, tmp2)))

        #####################################################################################
        #                                   END OF YOUR CODE                                #
        #####################################################################################

        # solve QP problem
        solution = cvxopt.solvers.qp(P, q, G, h, A, b)

        # Lagrange multipliers
        alpha = np.ravel(solution['x'])

        # Support vectors have non zero lagrange multipliers
        sv = alpha > 1e-5

        #this will actually give the indices of the support vectors
        ind = np.arange(len(alpha))[sv]

        # get alphas of support vector , Xs and ys too.
        self.alpha = alpha[sv]
        self.sv = X[sv]
        self.sv_y = y[sv]

        #####################################################################################
        ## TODO: Compute the Intercept b and Weight vector w.                              ##
        #####################################################################################
        # Intercept
        self.b = 0
        for n in range(len(self.alpha)):
            self.b += self.sv_y[n]
            self.b -= np.sum(self.alpha * self.sv_y * K[ind[n],sv])
        self.b /= len(self.alpha)

        # Weight vector
        if self.kernel == linear_kernel:
            self.w = np.zeros(n_features)
            for n in range(len(self.alpha)):
                self.w += self.alpha[n] * self.sv_y[n] * self.sv[n]
        else:
            self.w = None #Guidance: for non-linear case this should be None. (do not change)
        #####################################################################################
        #                                   END OF YOUR CODE                                #
        #####################################################################################

    def predict(self, X):
        if self.w is not None:
            return np.sign(np.dot(X, self.w) + self.b)
        else:
        #####################################################################################
        ## TODO: For non-linear case, implement the kernel trick to predict the label.     ##
        #####################################################################################
            y_predict = np.zeros(len(X))
            for i in range(len(X)):
                s = 0
                for alpha, sv_y, sv in zip(self.alpha, self.sv_y, self.sv):
                    s += alpha * sv_y * self.kernel(X[i], sv, self.gamma)
                y_predict[i] = s
            return np.sign(y_predict + self.b)

        #####################################################################################
        #                                   END OF YOUR CODE                                #
        #####################################################################################

# %%
###################################################################################
## TODO: define 3 model same as previous part (SVM Using sklearn) and evaluate   ##
## them. Note that for comaparing your result with that part for each kernel use ##
## same parameters in both parts.                                                ##
###################################################################################

# linear kernel

SVCClf = MySVM(kernel = linear_kernel, C=1)
SVCClf.fit(X_train, y_train, 1 / (X_train.shape[1] + X_train.var()))
y_pred = SVCClf.predict(X_test)

print("results of MySVM linear kernel:", classification_report(y_test , y_pred))


# polynomial kernel

SVCClf = MySVM(kernel = polynomial_kernel, C=1)
SVCClf.fit(X_train, y_train, 1 / (X_train.shape[1] + X_train.var()))
y_pred = SVCClf.predict(X_test)

print("results of MySVM polynomial kernel:", classification_report(y_test , y_pred))

SVCClf = MySVM(kernel = rbf_kernel, C=1)
SVCClf.fit(X_train, y_train, 1 / (X_train.shape[1] + X_train.var()))
y_pred = SVCClf.predict(X_test)

# rbf kernel

print("results of Mysvm RBF kernel:", classification_report(y_test , y_pred))
# Out:
# results of MySVM linear kernel: (0.7926136363636364, 0.7329192546583851, 0.7972972972972973, 0.7637540453074434)
# results of MySVM polynomial kernel: (0.7897727272727273, 0.7080745341614907, 0.8085106382978723, 0.7549668874172185)
# results of Mysvm RBF kernel: (0.7784090909090909, 0.7515527950310559, 0.7610062893081762, 0.75625)

# %% [markdown]
# #### Question 2: Report best results.
#
#
#
# 1.  Best kernel: Linear
# 2.  Best Accuracy: 0.7926136363636364

# %% [markdown]
# ### Bonus Score - (10pts)
#
# In this step you can check other kernel functions or change parameters or any idea to get better result in compare with last section's results.

# %%
a = []
b = []
SVCClf = MySVM(kernel = rbf_kernel, C=1)
for gamma in np.linspace(1,20,20):  
    SVCClf.fit(X_train, y_train, gamma)
    y_pred = SVCClf.predict(X_test)
    a.append(classification_report(y_test , y_pred))
    b.append(y_pred)
result = max(a)
gamma = np.linspace(1,20,20)[a.index(max(a))]
print(f"Gamma of RBF kernel is: {gamma}")
print(f"results of Mysvm RBF kernel: {result}")
# Out:
# Gamma of RBF kernel is: 17.0
# results of Mysvm RBF kernel: (0.9261363636363636, 0.9440993788819876, 0.8994082840236687, 0.9212121212121213)

# %% [markdown]
# 1.  Best kernel: RBF(with gamma = 17)
# 2.  Best Accuracy: 0.9261363636363636
